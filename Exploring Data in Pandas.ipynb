# %%
import pandas as pd
data = pd.read_excel("D:\Data Analyst\Project\hotel_booking_2.xlsx")
#print(data)
print(data.head(10))
print(data.tail(10))
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  adults  \
# 0  Resort Hotel            0               2015               July       2
# 1  Resort Hotel            0               2015               July       2
# 2  Resort Hotel            0               2015               July       1
# 3  Resort Hotel            0               2015               July       1
# 4  Resort Hotel            0               2015               July       2
# 5  Resort Hotel            0               2015               July       2
# 6  Resort Hotel            0               2015               July       2
# 7  Resort Hotel            0               2015               July       2
# 8  Resort Hotel            1               2015               July       2
# 9  Resort Hotel            1               2015               July       2
#
#    children  babies country reserved_room_type assigned_room_type  \
# 0       0.0       0     PRT                  C                  C
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   hotel               119390 non-null  object
#  1   is_canceled         119390 non-null  int64
#  2   arrival_date_year   119390 non-null  int64
#  3   arrival_date_month  119390 non-null  object
#  4   adults              119390 non-null  int64
#  5   children            119386 non-null  float64
#  6   babies              119390 non-null  int64
#  7   country             118902 non-null  object
#  8   reserved_room_type  119390 non-null  object
#  9   assigned_room_type  119390 non-null  object
#  10  customer_type       119390 non-null  object
#  11  reservation_status  119390 non-null  object
#  12  Room_status         119390 non-null  object
#  13  Guest_type          119390 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 12.8+ MB
# ...

# %%
data.describe()
# Out:
#          is_canceled  arrival_date_year         adults       children  \
# count  119390.000000      119390.000000  119390.000000  119386.000000
# mean        0.370416        2016.156554       1.856403       0.103890
# std         0.482918           0.707476       0.579261       0.398561
# min         0.000000        2015.000000       0.000000       0.000000
# 25%         0.000000        2016.000000       2.000000       0.000000
# 50%         0.000000        2016.000000       2.000000       0.000000
# 75%         1.000000        2017.000000       2.000000       0.000000
# max         1.000000        2017.000000      55.000000      10.000000
#
#               babies
# count  119390.000000
# mean        0.007949
# std         0.097436
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        10.000000

# %%
print(data.isnull().sum())
# Out:
# hotel                   0
# is_canceled             0
# arrival_date_year       0
# arrival_date_month      0
# adults                  0
# children                4
# babies                  0
# country               488
# reserved_room_type      0
# assigned_room_type      0
# customer_type           0
# reservation_status      0
# Room_status             0
# Guest_type              0
# dtype: int64
